# %%
from nav2_simple_commander.robot_navigator import BasicNavigator
from geometry_msgs.msg import PoseStamped
from rclpy.duration import Duration
import rclpy

rclpy.init()
nav = BasicNavigator()

# %%
goal_0_0 = PoseStamped()
goal_0_0.header.frame_id = 'map'
goal_0_0.header.stamp = nav.get_clock().now().to_msg()
goal_0_0.pose.position.x = 12.218327522277832
goal_0_0.pose.position.y = -0.8236180543899536
goal_0_0.pose.position.z = -0.001434326171875
goal_0_0.pose.orientation.x = 0.0
goal_0_0.pose.orientation.y = 0.0
goal_0_0.pose.orientation.z = 0.0
goal_0_0.pose.orientation.w = 1.0

goal_0_2 = PoseStamped()
goal_0_2.header.frame_id = 'map'
goal_0_2.header.stamp = nav.get_clock().now().to_msg()
goal_0_2.pose.position.x = 9.801982879638672
goal_0_2.pose.position.y = -0.942884087562561
goal_0_2.pose.position.z = 0.006378173828125
goal_0_2.pose.orientation.x = 0.0
goal_0_2.pose.orientation.y = 0.0
goal_0_2.pose.orientation.z = 0.0
goal_0_2.pose.orientation.w = 1.0

goal_0_3 = PoseStamped()
goal_0_3.header.frame_id = 'map'
goal_0_3.header.stamp = nav.get_clock().now().to_msg()
goal_0_3.pose.position.x = 8.819838523864746
goal_0_3.pose.position.y = -1.037698745727539
goal_0_3.pose.position.z = 0.006439208984375
goal_0_3.pose.orientation.x = 0.0
goal_0_3.pose.orientation.y = 0.0
goal_0_3.pose.orientation.z = 0.0
goal_0_3.pose.orientation.w = 1.0

goal_0_4 = PoseStamped()
goal_0_4.header.frame_id = 'map'
goal_0_4.header.stamp = nav.get_clock().now().to_msg()
goal_0_4.pose.position.x = 7.803897380828857
goal_0_4.pose.position.y = -0.956307053565979
goal_0_4.pose.position.z = 0.006378173828125
goal_0_4.pose.orientation.x = 0.0
goal_0_4.pose.orientation.y = 0.0
goal_0_4.pose.orientation.z = 0.0
goal_0_4.pose.orientation.w = 1.0

goal_0_8 = PoseStamped()
goal_0_8.header.frame_id = 'map'
goal_0_8.header.stamp = nav.get_clock().now().to_msg()
goal_0_8.pose.position.x = 3.133058786392212
goal_0_8.pose.position.y = -0.9255504012107849
goal_0_8.pose.position.z = 0.006378173828125
goal_0_8.pose.orientation.x = 0.0
goal_0_8.pose.orientation.y = 0.0
goal_0_8.pose.orientation.z = 0.0
goal_0_8.pose.orientation.w = 1.0

goal_0_9 = PoseStamped()
goal_0_9.header.frame_id = 'map'
goal_0_9.header.stamp = nav.get_clock().now().to_msg()
goal_0_9.pose.position.x = 2.323103189468384
goal_0_9.pose.position.y = -0.8619217872619629
goal_0_9.pose.position.z = -0.001373291015625
goal_0_9.pose.orientation.x = 0.0
goal_0_9.pose.orientation.y = 0.0
goal_0_9.pose.orientation.z = 0.0
goal_0_9.pose.orientation.w = 1.0

goal_1_0 = PoseStamped()
goal_1_0.header.frame_id = 'map'
goal_1_0.header.stamp = nav.get_clock().now().to_msg()
goal_1_0.pose.position.x = 12.05482292175293
goal_1_0.pose.position.y = 0.15087635815143585
goal_1_0.pose.position.z = -0.0013427734375
goal_1_0.pose.orientation.x = 0.0
goal_1_0.pose.orientation.y = 0.0
goal_1_0.pose.orientation.z = 0.0
goal_1_0.pose.orientation.w = 1.0

goal_1_1 = PoseStamped()
goal_1_1.header.frame_id = 'map'
goal_1_1.header.stamp = nav.get_clock().now().to_msg()
goal_1_1.pose.position.x = 10.956733703613281
goal_1_1.pose.position.y = 0.10129224509000778
goal_1_1.pose.position.z = 0.006378173828125
goal_1_1.pose.orientation.x = 0.0
goal_1_1.pose.orientation.y = 0.0
goal_1_1.pose.orientation.z = 0.0
goal_1_1.pose.orientation.w = 1.0

goal_1_2 = PoseStamped()
goal_1_2.header.frame_id = 'map'
goal_1_2.header.stamp = nav.get_clock().now().to_msg()
goal_1_2.pose.position.x = 10.00500774383545
goal_1_2.pose.position.y = 0.09307911247015
goal_1_2.pose.position.z = -0.001434326171875
goal_1_2.pose.orientation.x = 0.0
goal_1_2.pose.orientation.y = 0.0
goal_1_2.pose.orientation.z = 0.0
goal_1_2.pose.orientation.w = 1.0

goal_1_4 = PoseStamped()
goal_1_4.header.frame_id = 'map'
goal_1_4.header.stamp = nav.get_clock().now().to_msg()
goal_1_4.pose.position.x = 7.598061561584473
goal_1_4.pose.position.y = 0.13974599540233612
goal_1_4.pose.position.z = -0.0013427734375
goal_1_4.pose.orientation.x = 0.0
goal_1_4.pose.orientation.y = 0.0
goal_1_4.pose.orientation.z = 0.0
goal_1_4.pose.orientation.w = 1.0

goal_1_5 = PoseStamped()
goal_1_5.header.frame_id = 'map'
goal_1_5.header.stamp = nav.get_clock().now().to_msg()
goal_1_5.pose.position.x = 6.768527507781982
goal_1_5.pose.position.y = 0.16778099536895752
goal_1_5.pose.position.z = -0.009246826171875
goal_1_5.pose.orientation.x = 0.0
goal_1_5.pose.orientation.y = 0.0
goal_1_5.pose.orientation.z = 0.0
goal_1_5.pose.orientation.w = 1.0

goal_1_6 = PoseStamped()
goal_1_6.header.frame_id = 'map'
goal_1_6.header.stamp = nav.get_clock().now().to_msg()
goal_1_6.pose.position.x = 5.586639881134033
goal_1_6.pose.position.y = 0.059272635728120804
goal_1_6.pose.position.z = -0.001434326171875
goal_1_6.pose.orientation.x = 0.0
goal_1_6.pose.orientation.y = 0.0
goal_1_6.pose.orientation.z = 0.0
goal_1_6.pose.orientation.w = 1.0

goal_1_7 = PoseStamped()
goal_1_7.header.frame_id = 'map'
goal_1_7.header.stamp = nav.get_clock().now().to_msg()
goal_1_7.pose.position.x = 4.286025047302246
goal_1_7.pose.position.y =  0.05895846709609032
goal_1_7.pose.position.z = 0.002471923828125
goal_1_7.pose.orientation.x = 0.0
goal_1_7.pose.orientation.y = 0.0
goal_1_7.pose.orientation.z = 0.0
goal_1_7.pose.orientation.w = 1.0

goal_1_8 = PoseStamped()
goal_1_8.header.frame_id = 'map'
goal_1_8.header.stamp = nav.get_clock().now().to_msg()
goal_1_8.pose.position.x = 3.271120548248291
goal_1_8.pose.position.y = -0.013676007278263569
goal_1_8.pose.position.z = 0.002471923828125
goal_1_8.pose.orientation.x = 0.0
goal_1_8.pose.orientation.y = 0.0
goal_1_8.pose.orientation.z = 0.0
goal_1_8.pose.orientation.w = 1.0

goal_1_9 = PoseStamped()
goal_1_9.header.frame_id = 'map'
goal_1_9.header.stamp = nav.get_clock().now().to_msg()
goal_1_9.pose.position.x = 2.331803560256958
goal_1_9.pose.position.y = -0.03235435485839844
goal_1_9.pose.position.z = 0.002471923828125
goal_1_9.pose.orientation.x = 0.0
goal_1_9.pose.orientation.y = 0.0
goal_1_9.pose.orientation.z = 0.0
goal_1_9.pose.orientation.w = 1.0

goal_1_10 = PoseStamped()
goal_1_10.header.frame_id = 'map'
goal_1_10.header.stamp = nav.get_clock().now().to_msg()
goal_1_10.pose.position.x = 1.2970057725906372
goal_1_10.pose.position.y = 0.08406653255224228
goal_1_10.pose.position.z = 0.002471923828125
goal_1_10.pose.orientation.x = 0.0
goal_1_10.pose.orientation.y = 0.0
goal_1_10.pose.orientation.z = 0.0
goal_1_10.pose.orientation.w = 1.0

goal_1_11 = PoseStamped()
goal_1_11.header.frame_id = 'map'
goal_1_11.header.stamp = nav.get_clock().now().to_msg()
goal_1_11.pose.position.x = 0.1861949861049652
goal_1_11.pose.position.y = -0.03474393114447594
goal_1_11.pose.position.z = 0.002471923828125
goal_1_11.pose.orientation.x = 0.0
goal_1_11.pose.orientation.y = 0.0
goal_1_11.pose.orientation.z = 0.0
goal_1_11.pose.orientation.w = 1.0

goal_2_0 = PoseStamped()
goal_2_0.header.frame_id = 'map'
goal_2_0.header.stamp = nav.get_clock().now().to_msg()
goal_2_0.pose.position.x = 12.139469146728516
goal_2_0.pose.position.y= 1.1134895086288452
goal_2_0.pose.position.z = -0.001434326171875
goal_2_0.pose.orientation.x = 0.0
goal_2_0.pose.orientation.y = 0.0
goal_2_0.pose.orientation.z = 0.0
goal_2_0.pose.orientation.w = 1.0

goal_2_2 = PoseStamped()
goal_2_2.header.frame_id = 'map'
goal_2_2.header.stamp = nav.get_clock().now().to_msg()
goal_2_2.pose.position.x = 9.75554370880127
goal_2_2.pose.position.y= 1.0912729501724243
goal_2_2.pose.position.z = -0.001434326171875
goal_2_2.pose.orientation.x = 0.0
goal_2_2.pose.orientation.y = 0.0
goal_2_2.pose.orientation.z = 0.0
goal_2_2.pose.orientation.w = 1.0

goal_2_3 = PoseStamped()
goal_2_3.header.frame_id = 'map'
goal_2_3.header.stamp = nav.get_clock().now().to_msg()
goal_2_3.pose.position.x = 8.71652603149414
goal_2_3.pose.position.y= 1.1626739501953125
goal_2_3.pose.position.z = 0.002471923828125
goal_2_3.pose.orientation.x = 0.0
goal_2_3.pose.orientation.y = 0.0
goal_2_3.pose.orientation.z = 0.0
goal_2_3.pose.orientation.w = 1.0

goal_2_4 = PoseStamped()
goal_2_4.header.frame_id = 'map'
goal_2_4.header.stamp = nav.get_clock().now().to_msg()
goal_2_4.pose.position.x = 7.581840991973877
goal_2_4.pose.position.y= 1.0971661806106567
goal_2_4.pose.position.z = 0.002471923828125
goal_2_4.pose.orientation.x = 0.0
goal_2_4.pose.orientation.y = 0.0
goal_2_4.pose.orientation.z = 0.0
goal_2_4.pose.orientation.w = 1.0

goal_2_5 = PoseStamped()
goal_2_5.header.frame_id = 'map'
goal_2_5.header.stamp = nav.get_clock().now().to_msg()
goal_2_5.pose.position.x = 6.730158805847168
goal_2_5.pose.position.y= 1.0823323726654053
goal_2_5.pose.position.z = -0.001434326171875
goal_2_5.pose.orientation.x = 0.0
goal_2_5.pose.orientation.y = 0.0
goal_2_5.pose.orientation.z = 0.0
goal_2_5.pose.orientation.w = 1.0

goal_2_7 = PoseStamped()
goal_2_7.header.frame_id = 'map'
goal_2_7.header.stamp = nav.get_clock().now().to_msg()
goal_2_7.pose.position.x = 6.730158805847168
goal_2_7.pose.position.y= 1.0823323726654053
goal_2_7.pose.position.z = -0.001434326171875
goal_2_7.pose.orientation.x = 0.0
goal_2_7.pose.orientation.y = 0.0
goal_2_7.pose.orientation.z = 0.0
goal_2_7.pose.orientation.w = 1.0


goal_2_8 = PoseStamped()
goal_2_8.header.frame_id = 'map'
goal_2_8.header.stamp = nav.get_clock().now().to_msg()
goal_2_8.pose.position.x = 3.271435022354126
goal_2_8.pose.position.y = 0.9541149139404297
goal_2_8.pose.position.z = 0.002471923828125
goal_2_8.pose.orientation.x = 0.0
goal_2_8.pose.orientation.y = 0.0
goal_2_8.pose.orientation.z = 0.0
goal_2_8.pose.orientation.w = 1.0


goal_2_9 = PoseStamped()
goal_2_9.header.frame_id = 'map'
goal_2_9.header.stamp = nav.get_clock().now().to_msg()
goal_2_9.pose.position.x = 2.3385095596313477
goal_2_9.pose.position.y = 0.954960823059082
goal_2_9.pose.position.z = -0.001434326171875
goal_2_9.pose.orientation.x = 0.0
goal_2_9.pose.orientation.y = 0.0
goal_2_9.pose.orientation.z = 0.0
goal_2_9.pose.orientation.w = 1.0


goal_2_10 = PoseStamped()
goal_2_10.header.frame_id = 'map'
goal_2_10.header.stamp = nav.get_clock().now().to_msg()
goal_2_10.pose.position.x = 1.1297811269760132
goal_2_10.pose.position.y = 1.0173070430755615
goal_2_10.pose.position.z = -0.001434326171875
goal_2_10.pose.orientation.x = 0.0
goal_2_10.pose.orientation.y = 0.0
goal_2_10.pose.orientation.z = 0.0
goal_2_10.pose.orientation.w = 1.0

# %%
list_a = [goal_1_2, goal_0_0]

# %%
nav.goToPose(list_a[1])

i=0
while not nav.isTaskComplete():
    i = i+1
    feedback = nav.getFeedback()
    if feedback and i % 5 == 0:
        print("Distance remaining : " + str(feedback.distance_remaining) + " m")
    
    if Duration.from_msg(feedback.navigation_time) > Duration(seconds = 60.0):
        nav.cancelTask()
        
nav.goToPose(list_a[0])

i=0
while not nav.isTaskComplete():
    i = i+1
    feedback = nav.getFeedback()
    if feedback and i % 5 == 0:
        print("Distance remaining : " + str(feedback.distance_remaining) + " m")
    
    if Duration.from_msg(feedback.navigation_time) > Duration(seconds = 60.0):
        nav.cancelTask()
# Out:
# [INFO] [1678883492.368820993] [basic_navigator]: Navigating to goal: 12.218327522277832 -0.8236180543899536...
# Distance remaining : 2.5052390098571777 m
# Distance remaining : 2.4052388668060303 m
# Distance remaining : 2.2552390098571777 m
# Distance remaining : 2.1552388668060303 m
# Distance remaining : 2.054629325866699 m
# Distance remaining : 1.9046294689178467 m
# Distance remaining : 1.8046298027038574 m
# Distance remaining : 1.6546332836151123 m
# Distance remaining : 1.5546424388885498 m
# Distance remaining : 1.4546774625778198 m
# Distance remaining : 1.3547557592391968 m
# Distance remaining : 1.2054378986358643 m
# Distance remaining : 0.9537538290023804 m
# Distance remaining : 0.8846749663352966 m
# Distance remaining : 0.7720033526420593 m
# Distance remaining : 0.6521925330162048 m
# Distance remaining : 0.550399899482727 m
# Distance remaining : 0.4417654871940613 m
# Distance remaining : 0.3621320426464081 m
# Distance remaining : 0.26213204860687256 m
# ...

# %%
my_map_coordinate = []
my_map_layer = []

cor_x = 12.829639291763306  # 1씩 빼세요
cor_y = -1.712965272180736065 # 0.9 씩 더하세요.

for i in range(len(my_map)):
    cor_y = cor_y + 0.9
    for j in range(len(my_map[0])):
        cor_x = cor_x - 1
        if my_map[i][j] == 1:
            my_map_layer.append(None)
        elif my_map[i][j] == 0:
            goal = [cor_x, cor_y]
            my_map_layer.append(goal)
    my_map_coordinate.append(my_map_layer)
    my_map_layer = []
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_41029/2804191293.py in <module>
#       5 cor_y = -1.712965272180736065 # 0.9 씩 더하세요.
#       6
# ----> 7 for i in range(len(my_map)):
#       8     cor_y = cor_y + 0.9
#       9     for j in range(len(my_map[0])):
#
# NameError: name 'my_map' is not defined

# %%
goal_ = PoseStamped()
goal_.header.frame_id = 'map'
goal_.header.stamp = nav.get_clock().now().to_msg()
goal_.pose.position.x = 12.139469146728516
goal_.pose.position.y= 1.1134895086288452
goal_.pose.position.z = -0.001434326171875
goal_.pose.orientation.x = 0.0
goal_.pose.orientation.y = 0.0
goal_.pose.orientation.z = 0.0
goal_.pose.orientation.w = 1.0
print(goal_)

nav.goToPose(goal_)

i=0
while not nav.isTaskComplete():
    i = i+1
    feedback = nav.getFeedback()
    if feedback and i % 5 == 0:
        print("Distance remaining : " + str(feedback.distance_remaining) + " m")
    
    if Duration.from_msg(feedback.navigation_time) > Duration(seconds = 60.0):
        nav.cancelTask()
# Out:
# geometry_msgs.msg.PoseStamped(header=std_msgs.msg.Header(stamp=builtin_interfaces.msg.Time(sec=1678884140, nanosec=599076424), frame_id='map'), pose=geometry_msgs.msg.Pose(position=geometry_msgs.msg.Point(x=12.139469146728516, y=1.1134895086288452, z=-0.001434326171875), orientation=geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.0, w=1.0)))
# [INFO] [1678884140.601487176] [basic_navigator]: Navigating to goal: 12.139469146728516 1.1134895086288452...
# Distance remaining : 0.25 m
# Distance remaining : 0.25 m
# Distance remaining : 0.25 m
# Distance remaining : 0.25 m
# Distance remaining : 0.25 m
# Distance remaining : 0.25 m
# Distance remaining : 0.20000000298023224 m
# Distance remaining : 0.20000000298023224 m
# Distance remaining : 0.25 m
# Distance remaining : 0.25 m
# Distance remaining : 0.25 m
# Distance remaining : 0.25 m

# %%
goal_ = PoseStamped()
goal_.header.frame_id = 'map'
goal_.header.stamp = nav.get_clock().now().to_msg()
goal_.pose.position.x = 9.139469146728516
goal_.pose.position.y= 2.1134895086288452
goal_.pose.position.z = -0.001434326171875
goal_.pose.orientation.x = 0.0
goal_.pose.orientation.y = 0.0
goal_.pose.orientation.z = 0.0
goal_.pose.orientation.w = 1.0
print(goal_)

nav.goToPose(goal_)

i=0
while not nav.isTaskComplete():
    i = i+1
    feedback = nav.getFeedback()
    if feedback and i % 5 == 0:
        print("Distance remaining : " + str(feedback.distance_remaining) + " m")
    
    if Duration.from_msg(feedback.navigation_time) > Duration(seconds = 60.0):
        nav.cancelTask()
# Out:
# geometry_msgs.msg.PoseStamped(header=std_msgs.msg.Header(stamp=builtin_interfaces.msg.Time(sec=1678884152, nanosec=210633838), frame_id='map'), pose=geometry_msgs.msg.Pose(position=geometry_msgs.msg.Point(x=9.139469146728516, y=2.113489508628845, z=-0.001434326171875), orientation=geometry_msgs.msg.Quaternion(x=0.0, y=0.0, z=0.0, w=1.0)))
# [INFO] [1678884152.212131829] [basic_navigator]: Navigating to goal: 9.139469146728516 2.113489508628845...
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# ...

# %%
cor_x = 12.8  # 1씩 빼세요
cor_y = -1.7 # 0.9 씩 더하세요.
goal_2_10 = PoseStamped()
goal_2_10.header.frame_id = 'map'
goal_2_10.header.stamp = nav.get_clock().now().to_msg()
goal_2_10.pose.position.x = 12.8
goal_2_10.pose.position.y = -0.84
goal_2_10.pose.position.z = -0.001434326171875
goal_2_10.pose.orientation.x = 0.0
goal_2_10.pose.orientation.y = 0.0
goal_2_10.pose.orientation.z = 0.0
goal_2_10.pose.orientation.w = 1.0

nav.goToPose(goal_2_10)

i=0
while not nav.isTaskComplete():
    i = i+1
    feedback = nav.getFeedback()
    if feedback and i % 5 == 0:
        print("Distance remaining : " + str(feedback.distance_remaining) + " m")
    
    if Duration.from_msg(feedback.navigation_time) > Duration(seconds = 60.0):
        nav.cancelTask()
# Out:
# [INFO] [1678884457.342829875] [basic_navigator]: Navigating to goal: 12.8 -0.84...
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# Distance remaining : 0.0 m
# ...

# %%
cor_x = 12.8  # 1씩 빼세요
cor_y = -1.7 # 0.9 씩 더하세요.
goal_2_10 = PoseStamped()
goal_2_10.header.frame_id = 'map'
goal_2_10.header.stamp = nav.get_clock().now().to_msg()
goal_2_10.pose.position.x = 12.2
goal_2_10.pose.position.y = -0.35
goal_2_10.pose.position.z = -0.001434326171875
goal_2_10.pose.orientation.x = 0.0
goal_2_10.pose.orientation.y = 0.0
goal_2_10.pose.orientation.z = 0.0
goal_2_10.pose.orientation.w = 1.0

nav.goToPose(goal_2_10)

i=0
while not nav.isTaskComplete():
    i = i+1
    feedback = nav.getFeedback()
    if feedback and i % 5 == 0:
        print("Distance remaining : " + str(feedback.distance_remaining) + " m")
    
    if Duration.from_msg(feedback.navigation_time) > Duration(seconds = 60.0):
        nav.cancelTask()
# Out:
# [INFO] [1678884660.099208635] [basic_navigator]: Navigating to goal: 12.2 -0.35...
# Distance remaining : 13.025854110717773 m
# Distance remaining : 12.925853729248047 m
# Distance remaining : 12.776704788208008 m
# Distance remaining : 12.676704406738281 m
# Distance remaining : 12.527420997619629 m
# Distance remaining : 12.377280235290527 m
# Distance remaining : 12.22545337677002 m
# Distance remaining : 12.124446868896484 m
# Distance remaining : 11.97200870513916 m
# Distance remaining : 11.871352195739746 m
# Distance remaining : 11.722052574157715 m
# Distance remaining : 11.621800422668457 m
# Distance remaining : 11.520158767700195 m
# Distance remaining : 11.370159149169922 m
# Distance remaining : 11.270158767700195 m
# Distance remaining : 11.170159339904785 m
# Distance remaining : 11.020158767700195 m
# Distance remaining : 10.920159339904785 m
# Distance remaining : 10.770158767700195 m
# Distance remaining : 10.670159339904785 m
# ...

# %%
cor_x = 12.8  # 1씩 빼세요
cor_y = -1.7 # 0.9 씩 더하세요.
goal_2_10 = PoseStamped()
goal_2_10.header.frame_id = 'map'
goal_2_10.header.stamp = nav.get_clock().now().to_msg()
goal_2_10.pose.position.x = 10.2
goal_2_10.pose.position.y = -0.35
goal_2_10.pose.position.z = -0.001434326171875
goal_2_10.pose.orientation.x = 0.0
goal_2_10.pose.orientation.y = 0.0
goal_2_10.pose.orientation.z = 0.0
goal_2_10.pose.orientation.w = 1.0

nav.goToPose(goal_2_10)

i=0
while not nav.isTaskComplete():
    i = i+1
    feedback = nav.getFeedback()
    if feedback and i % 5 == 0:
        print("Distance remaining : " + str(feedback.distance_remaining) + " m")
    
    if Duration.from_msg(feedback.navigation_time) > Duration(seconds = 60.0):
        nav.cancelTask()
# Out:
# [INFO] [1678884718.237319158] [basic_navigator]: Navigating to goal: 10.2 -0.35...
# Distance remaining : 2.04390287399292 m
# Distance remaining : 2.04390287399292 m
# Distance remaining : 2.079542636871338 m
# Distance remaining : 2.079542636871338 m
# Distance remaining : 2.0512216091156006 m
# Distance remaining : 2.0512216091156006 m
# Distance remaining : 2.1016902923583984 m
# Distance remaining : 2.1016902923583984 m
# Distance remaining : 2.123037815093994 m
# Distance remaining : 2.123037815093994 m
# Distance remaining : 2.143709421157837 m
# Distance remaining : 2.143709421157837 m
# Distance remaining : 2.143709421157837 m
# Distance remaining : 2.143709421157837 m
# Distance remaining : 2.1384525299072266 m
# Distance remaining : 2.1384525299072266 m
# Distance remaining : 2.143709421157837 m
# Distance remaining : 2.143709421157837 m
# Distance remaining : 2.1481330394744873 m
# Distance remaining : 2.1481330394744873 m
# Distance remaining : 2.1409401893615723 m
# ...
